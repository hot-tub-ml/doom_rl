# %% [markdown]
# # Predict played action from frame sequences

# %%
import numpy as np           
import tensorflow as tf
import ourlib
import matplotlib.pyplot as plt
plt.style.use(['dark_background'])  # n00bz who dont
ourlib.init_basic_env()  # init basic environment

# %% [markdown]
# ## Check pre-processing and test an episode

# %% [markdown]
# Play episode and return pre-processed frames. Replay episode if number of frames is little.

# %%
frames, labels = ourlib.play_episode()
len(frames)

# %% [markdown]
# Display some randomly-chosen frames and corresponding action performed.

# %%
n_frames = 5
fig, axs = plt.subplots(ncols=n_frames, figsize=(20, 10))
ixs = list(np.random.choice(range(len(frames)), size=n_frames))
for ax,ix in zip(axs, ixs):
    ax.axis('off')
    ax.imshow(frames[ix])
    ax.set_title('Frame: ' + str(ix) + ' Action: ' + str(labels[ix]))

# %% [markdown]
# Display first frames

# %%
n_frames = 6 # per row
n_rows = 4
ixs = range(n_frames*n_rows)
fig, axs = plt.subplots(ncols=n_frames, nrows=n_rows, figsize=(20, 10))
for coord, ix in enumerate(ixs):
    coord = np.unravel_index(coord, dims=(n_rows, n_frames)) # there must be a simpler way
    axs[coord].axis('off')
    axs[coord].imshow(frames[ix])
    axs[coord].set_title('Frame: ' + str(ix) + ' Action: ' + str(labels[ix]))

# %% [markdown]
# Display last frames

# %%
n_frames = 6 # per row
n_rows = 2
ixs = reversed(range(len(frames)-(n_frames*n_rows), len(frames)))
fig, axs = plt.subplots(ncols=n_frames, nrows=n_rows, figsize=(20, 10))
for coord, ix in enumerate(ixs):
    coord = np.unravel_index(coord, dims=(n_rows, n_frames)) # there must be a simpler way
    axs[coord].axis('off')
    axs[coord].imshow(frames[ix])
    axs[coord].set_title('Frame: ' + str(ix) + ' Action: ' + str(labels[ix]))

# %% [markdown]
# The goal of the NN is to predict the sequence of actions played, given a short part of the episode replay. To each frame we stack the 5 next ones (for a total of six) and annotate the corresponding action as the one from the first frame. Each stack corresponds to a training example.

# %%
history_length=6
stacks = ourlib.stack_frames(frames, history_length)
labels = labels[:-history_length]
fig, axs = plt.subplots(nrows=5, figsize=(10, 10))
for ix, ax in enumerate(axs):
    ax.axis('off')
    ax.set_title('Action: '+str(labels[ix]))
    ax.imshow(stacks[ix])

# %% [markdown]
# ## Further pre-process and feed into simple CNN

# %% [markdown]
# Load simple model and print architecture

# %%
model = ourlib.frames2action_model()
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 46, 286, 32)       320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 23, 143, 32)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 21, 141, 32)       9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 70, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 68, 32)         9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 22, 32)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 1408)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                45088
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 99
# =================================================================
# Total params: 64,003
# Trainable params: 64,003
# Non-trainable params: 0
# _________________________________________________________________

# %%
assert len(labels) == len(stacks)

# %% [markdown]
# Pre-process stack to add a fourth dummy dim

# %%
new_shape = stacks.shape + (1,) # add fourth dummy dim
stacks = np.reshape(stacks, new_shape)
stacks.shape
# Out:
# (294, 48, 288, 1)

# %% [markdown]
# 1-hot encoding of action labels (dummy trap not accounted for)

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
le = LabelEncoder()
oh = OneHotEncoder()
labels_le = le.fit_transform(labels)
labels_le = np.reshape(labels_le, (-1, 1))
labels_le.shape
labels_oh = oh.fit_transform(labels_le)
labels_oh.shape
# Out:
# /Users/tommasobiancalani/anaconda3/envs/py27-dqdoom/lib/python2.7/site-packages/sklearn/preprocessing/_encoders.py:363: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# (294, 3)

# %% [markdown]
# Fit model to our small training set

# %%
model.fit(stacks, labels_oh, epochs=1, batch_size=64);
# Out:
# Epoch 1/1
# 294/294 [==============================] - 4s 15ms/step - loss: 1.0990 - acc: 0.3367

# %%
from ourlib import *

# %%
trn_images = None
trn_labels = None
while True:
    frames, labels = play_episode()
    stacks = stack_frames(frames, history_length)
    labels = labels[:-history_length]
    if trn_images is None or trn_labels is None:
        trn_images = stacks
        trn_labels = labels
    else:
        try:
            trn_images = np.append(trn_images, stacks, axis=0)
            trn_labels = np.append(trn_labels, labels)
        except:
            print trn_images.shape, stacks.shape
    if len(trn_labels) > 2000:
        break
# Out:
# (0,) (294, 48, 288)
# (0,) (65, 48, 288)
# (0,) (14, 48, 288)
# (0,) (294, 48, 288)
# (0,) (187, 48, 288)
# (0,) (77, 48, 288)
# (0,) (22, 48, 288)
# (0,) (294, 48, 288)
# (0,) (294, 48, 288)
# (0,) (9, 48, 288)
# (0,) (294, 48, 288)
# (0,) (294, 48, 288)
# (0,) (294, 48, 288)
# (0,) (294, 48, 288)
# (0,) (166, 48, 288)
# ----------------------------------------------
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-34-b6f827d6391c> in <module>()
#       2 trn_labels = None
#       3 while True:
# ----> 4     frames, labels = play_episode()
#       5     stacks = stack_frames(frames, history_length)
#       6     labels = labels[:-history_length]
#
# /Users/tommasobiancalani/git/my_notebooks/doom_rl/ourlib.py in play_episode()
#      57         state = game.get_state()
#      58         img = state.screen_buffer
# ---> 59         frame = preprocess_frame(img)
#      60         action = random.choice(possible_actions)
#      61         labels.append(action_dict[repr(action)])
#
# /Users/tommasobiancalani/git/my_notebooks/doom_rl/ourlib.py in preprocess_frame(img)
#      39     frame /= 255
#      40 #     plt.imshow(frame);
# ---> 41     frame2 = skimage.transform.resize(frame, [48, 48])
#      42 #     plt.imshow(frame2);
#      43     return frame2
#
# /Users/tommasobiancalani/anaconda3/envs/py27-dqdoom/lib/python2.7/site-packages/skimage/transform/_warps.pyc in resize(image, output_shape, order, mode, cval, clip, preserve_range, anti_aliasing, anti_aliasing_sigma)
#     162             dst_corners[:, 1] = factors[0] * (src_corners[:, 1] + 0.5) - 0.5
#     163
# --> 164             tform = AffineTransform()
#     165             tform.estimate(src_corners, dst_corners)
#     166
#
# /Users/tommasobiancalani/anaconda3/envs/py27-dqdoom/lib/python2.7/site-packages/skimage/transform/_geometric.pyc in __init__(self, matrix, scale, rotation, shear, translation)
#     756                  translation=None):
#     757         params = any(param is not None
# --> 758                      for param in (scale, rotation, shear, translation))
#     759
#     760         if params and matrix is not None:
#
# /Users/tommasobiancalani/anaconda3/envs/py27-dqdoom/lib/python2.7/site-packages/skimage/transform/_geometric.pyc in <genexpr>(***failed resolving arguments***)
#     755     def __init__(self, matrix=None, scale=None, rotation=None, shear=None,
#     756                  translation=None):
# --> 757         params = any(param is not None
#     758                      for param in (scale, rotation, shear, translation))
#     759
#
# KeyboardInterrupt:

# %%
trn_images.shape, trn_labels.shape
# Out:
# ((2258, 48, 288), (2258,))

# %%
images, labels = ourlib.get_images_labels(1000)
images.shape, labels.shape
# Out:
# ----------------------------------------------
# ValueError   Traceback (most recent call last)
# <ipython-input-28-d671bcdc387d> in <module>()
# ----> 1 images, labels = ourlib.get_images_labels(1000)
#       2 images.shape, labels.shape
#
# /Users/tommasobiancalani/git/my_notebooks/doom_rl/ourlib.py in get_images_labels(number, history_length)
#     106             trn_labels = labels
#     107         else:
# --> 108             trn_images = np.append(trn_images, stacks, axis=0)
#     109             trn_labels = np.append(trn_labels, labels)
#     110         if len(trn_labels) > number:
#
# /Users/tommasobiancalani/anaconda3/envs/py27-dqdoom/lib/python2.7/site-packages/numpy/lib/function_base.pyc in append(arr, values, axis)
#    4526         values = ravel(values)
#    4527         axis = arr.ndim-1
# -> 4528     return concatenate((arr, values), axis=axis)
#
# ValueError: all the input arrays must have same number of dimensions
